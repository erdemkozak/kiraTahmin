# %% [markdown]
# #verilerin istatiksel olarak incelenmesi ve aykırı değerlerin ayıklanması

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("housing.csv")
